# %%
import gspread
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import datetime

# %%
s = requests.Session()
headerbse ={
'scheme':'https',
'Accept':'application/json, text/plain, */*',
'Accept-Language':'en-US,en;q=0.8',
'Referer':'https://www.bseindia.com/',
'Sec-Ch-Ua':'"Not_A Brand";v="8", "Chromium";v="120", "Brave";v="120"',
'Sec-Ch-Ua-Mobile': '?0',
'Sec-Ch-Ua-Platform':'"Windows"',
'Sec-Fetch-Mode':'cors',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

# %%
DateFrom = (datetime.datetime.now() - datetime.timedelta(days = 7)).strftime('%Y%m%d')
DateTo = datetime.datetime.now().strftime('%Y%m%d')
#Date_From = 20240101
#Kab Tak
#Date_To = 20240116

# %%
url = f'https://api.bseindia.com/BseIndiaAPI/api/AnnSubCategoryGetData/w?pageno=1&strCat=New+Listing&strPrevDate={DateFrom}&strScrip=&strSearch=P&strToDate={DateTo}&strType=C&subcategory=-1'
page = s.get(url,headers= headerbse)

# %%
Data = page.json()['Table']

# %%
if page.status_code == 200:
    gc = gspread.service_account(filename='creds.json')
    spreadsheet_name = 'Notifications and Listings'
    sheet_number = 0 
    sheet_name = 'BSE_Listing'
    sh = gc.open(spreadsheet_name).worksheet(sheet_name)
else :
    print(page.status_code)

# %%
if page.status_code == 200:
    existing_data_range = sh.range('A2:L' + str(sh.row_count))
    for cell in existing_data_range:
        cell.value = ''

    sh.update_cells(existing_data_range)
else :
    pass

# %%
if page.status_code == 200:
    df = pd.DataFrame(Data)
    values_lists = []
    df_dict = df.to_dict(orient='records')
    for data in df_dict:
        values_lists.append([str(data['NEWS_DT']),str(data['SCRIP_CD']), str(data['SLONGNAME']), str(data['NSURL']),str(data['SUBCATNAME'])])
    sh.append_row([f'Batch ran at: {datetime.datetime.now()}'])
    sh.append_rows(values_lists)
else:
    pass

# %%
df.head(10)
# Out:
#                                  NEWSID  SCRIP_CD  \
# 0  16536fb4-814a-453e-bd59-ca3561ccb05c    544107
# 1  b4a8cfc6-544f-46a3-a2c4-69bb1da092c2    544106
# 2  5120b6e5-1850-468a-b784-cb4884f050be    544105
# 3  b2ee479e-ce5e-4b35-b156-b03bfbc1faa8    544101
# 4  26de7f01-133e-477c-bcfe-42669c965ea9    544100
# 5  c6b3282c-dda2-4c9a-8184-ce616aa57768    544095
# 6  e6e926a5-627f-4edf-a756-a864c569f182    544094
#
#                                           XML_NAME  \
# 0  ANN_544107_16536FB4-814A-453E-BD59-CA3561CCB05C
# 1  ANN_544106_B4A8CFC6-544F-46A3-A2C4-69BB1DA092C2
# 2  ANN_544105_5120B6E5-1850-468A-B784-CB4884F050BE
# 3  ANN_544101_B2EE479E-CE5E-4B35-B156-B03BFBC1FAA8
# 4  ANN_544100_26DE7F01-133E-477C-BCFE-42669C965EA9
# 5  ANN_544095_C6B3282C-DDA2-4C9A-8184-CE616AA57768
# 6  ANN_544094_E6E926A5-627F-4EDF-A756-A864C569F182
#
#                                              NEWSSUB                    DT_TM  \
# 0  BLS E-Services Ltd - 544107 - Listing of equit...  2024-02-06T08:01:12.403
# 1  Mayank Cattle Food Ltd - 544106 - Listing of e...  2024-02-05T08:29:02.183
# 2  Harshdeep Hortico Ltd - 544105 - Listing of eq...   2024-02-05T08:28:44.47
# 3  Brisk Technovision Ltd - 544101 - Listing of e...   2024-01-31T07:44:56.14
# 4  Nova Agritech Ltd - 544100 - Listing of equity...  2024-01-31T07:44:38.357
# 5  EPACK Durable Ltd - 544095 - Listing of Equity...  2024-01-30T08:01:02.727
# 6  Euphoria Infotech (India) Ltd - 544094 - Listi...   2024-01-30T08:00:41.14
#
#                    NEWS_DT  CRITICALNEWS ANNOUNCEMENT_TYPE QUARTER_ID  \
# 0  2024-02-06T08:01:12.403             1                 A       None
# 1  2024-02-05T08:29:02.183             1                 A       None
# 2   2024-02-05T08:28:44.47             1                 A       None
# 3   2024-01-31T07:44:56.14             1                 A       None
# 4  2024-01-31T07:44:38.357             1                 A       None
# 5  2024-01-30T08:01:02.727             1                 A       None
# 6   2024-01-30T08:00:41.14             1                 A       None
#
#   FILESTATUS  ...                                              NSURL  \
# 0      N      ...  https://www.bseindia.com/stock-share-price/bls...
# 1      N      ...  https://www.bseindia.com/stock-share-price/may...
# 2      N      ...  https://www.bseindia.com/stock-share-price/har...
# 3      N      ...  https://www.bseindia.com/stock-share-price/bri...
# 4      N      ...  https://www.bseindia.com/stock-share-price/nov...
# 5      N      ...  https://www.bseindia.com/stock-share-price/epa...
# 6      N      ...  https://www.bseindia.com/stock-share-price/eup...
#
#                        SLONGNAME AGENDA_ID TotalPageCnt  News_submission_dt  \
# 0             BLS E-Services Ltd        45            1                None
# 1         Mayank Cattle Food Ltd        45            1                None
# 2          Harshdeep Hortico Ltd        45            1                None
# 3         Brisk Technovision Ltd        45            1                None
# 4              Nova Agritech Ltd        45            1                None
# 5              EPACK Durable Ltd        45            1                None
# 6  Euphoria Infotech (India) Ltd        45            1                None
#
#                   DissemDT  TimeDiff Fld_Attachsize   SUBCATNAME  \
# 0  2024-02-06T08:01:12.403      None           None  New Listing
# 1  2024-02-05T08:29:02.183      None           None  New Listing
# 2   2024-02-05T08:28:44.47      None           None  New Listing
# 3   2024-01-31T07:44:56.14      None           None  New Listing
# 4  2024-01-31T07:44:38.357      None           None  New Listing
# 5  2024-01-30T08:01:02.727      None           None  New Listing
# 6   2024-01-30T08:00:41.14      None           None  New Listing
#
#    AUDIO_VIDEO_FILE
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
#
# [7 rows x 27 columns]
