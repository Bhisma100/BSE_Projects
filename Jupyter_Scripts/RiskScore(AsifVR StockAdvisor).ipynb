# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoAlertPresentException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import json
import pickle

# %%
# driver = webdriver.Chrome()
# # driver.maximize_window()
# cookies = driver.get_cookies()
# url = 'https://www.valueresearchstocks.com/landing/'
# driver.get(url)
# driver.find_element(By.XPATH,'//*[@id="login_hero"]').click()
# time.sleep(1)
# driver.find_element(By.XPATH,'/html/body/section/div/div/div/div/div/div[3]/div/div[1]/button[2]').click()
# time.sleep(1)
# driver.find_element(By.XPATH,'//*[@id="username"]').send_keys('ravikant@valueresearch.in')
# driver.find_element(By.XPATH,'//*[@id="proceed-btn"]').click()
# time.sleep(1)
# driver.find_element(By.XPATH,'//*[@id="login_password"]').send_keys('ravikant@9876')
# driver.find_element(By.XPATH,'//*[@id="login-btn"]').click()
# WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//*[@id="onesignal-slidedown-dialog"]')))
# time.sleep(2)
# close_button = driver.find_element(By.XPATH, '//*[@id="onesignal-slidedown-cancel-button"]')
# close_button.click()
# print("Pop-up closed.")
# with open('cookies.pkl', 'wb') as f:
#     pickle.dump(cookies, f)
# WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//*[@id="sec-menu"]/div/div[1]/ul/li[2]/a'))).click()
# driver.find_element(By.XPATH,'//*[@id="filter-option-small-case"]').click()
# driver.find_element(By.XPATH, '//*[@id="filter-option-small-case"]/option[1]').click()
# time.sleep(5)
# cookies = driver.get_cookies()
# with open('cookies.pkl', 'wb') as f:
#     pickle.dump(cookies, f)
# r = driver.page_source
# All_Links = []
# Scorelist = []
# soup = bs(r,'html.parser')
# table = soup.find_all('table')
# for n in range (0,3):
#     for rows in table[n].find_all('tr'):
#         row = rows.find_all('td')
#         for links in row:
#             link = links.find('a')
#             if link:
#                 href_value = link.get('href')
#                 l = f'https://www.valueresearchstocks.com/{href_value}'
#                 All_Links.append(l)
# for link in All_Links:
#     driver.get(link)
#     # Add cookies to maintain session
#     for cookie in cookies:
#         driver.add_cookie(cookie)
#     # driver.find_element(By.XPATH,'//*[@id="premium-coverage-tab"]/div/div/div/ul/li[2]/a').click()
#     driver.execute_script("window.scrollTo(0, 0);")
#     time.sleep(1)
#     element_text = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/h1').text
#     Dict = {'Name': element_text}
#     print(element_text)
#     Scorelist.append(Dict)
#     try:
#         driver.find_element(By.XPATH,'//*[@id="premium-coverage-tab"]/div/div/div/ul/li[2]/a').click()
#         score = driver.find_element(By.XPATH,'//*[@id="risk-score"]/div[1]/div/div[2]/div/div/div/div[2]/h3').text
#         secondline = score.split('\n')
#         onlyscore = secondline[1]
#         Dict = {'Risk Score': secondline[1]}
#         Scorelist.append(Dict)
#     except:
#         Dict = {'Risk Score': 'NA'}
#         print('NA')
#         Scorelist.append(Dict)
# time.sleep(5)  


# driver.quit()

# %%
# Data = []
# for i in range(0, len(Scorelist), 2):
#     data = {}
#     for entry in Scorelist[i:i+2]:
#         for key, value in entry.items():
#             data[key] = value
#     Data.append(data)

# %%
# df = pd.DataFrame(Data)
# df.to_csv(r'C:\Users\Ashish Pal\Desktop\BSE_Stock_Price\StockRisckCore.csv',index=False)

# %%
# settings = {
#     "appState": {
#         "recentDestinations": [{
#             "id": "Save as PDF",
#             "origin": "local",
#             "account": ""
#         }],
#         "selectedDestinationId": "Save as PDF",
#         "version": 2
#     }  
# }
# prefs = {
#     'printing.print_preview_sticky_settings': json.dumps(settings)
# }
download_directory = r'C:\Users\Ashish Pal\Desktop\KathikPdfs'
chrome_options = Options()
chrome_options.add_experimental_option("prefs", {
    "download.default_directory": download_directory,
    "printing.print_preview_sticky_settings": json.dumps({
        "appState": {
            "recentDestinations": [{
                "id": "Save as PDF",
                "origin": "local",
                "account": ""
            }],
            "selectedDestinationId": "Save as PDF",
            "version": 2
        }
    })
})
chrome_options.add_argument('--kiosk-printing')
driver = webdriver.Chrome(options=chrome_options)
cookies = driver.get_cookies()
url = 'https://www.valueresearchonline.com/login/?site-code=stad&target=%2F'
driver.get(url,)
time.sleep(1)
driver.find_element(By.XPATH,'/html/body/section/div/div/div/div/div/div[3]/div/div[1]/button[2]').click()
time.sleep(1)
driver.find_element(By.XPATH,'//*[@id="username"]').send_keys('ravikant@valueresearch.in')
driver.find_element(By.XPATH,'//*[@id="proceed-btn"]').click()
time.sleep(1)
driver.find_element(By.XPATH,'//*[@id="login_password"]').send_keys('ravikant@9876')
driver.find_element(By.XPATH,'//*[@id="login-btn"]').click()
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//*[@id="onesignal-slidedown-dialog"]')))
time.sleep(2)
close_button = driver.find_element(By.XPATH, '//*[@id="onesignal-slidedown-cancel-button"]')
close_button.click()
print("Pop-up closed.")
with open('cookies.pkl', 'wb') as f:
    pickle.dump(cookies, f)
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//*[@id="sec-menu"]/div/div[1]/ul/li[2]/a'))).click()
driver.find_element(By.XPATH,'//*[@id="filter-option-small-case"]').click()
driver.find_element(By.XPATH, '//*[@id="filter-option-small-case"]/option[1]').click()
time.sleep(5)
cookies = driver.get_cookies()
with open('cookies.pkl', 'wb') as f:
    pickle.dump(cookies, f)
r = driver.page_source
All_Links = []
Scorelist = []
soup = bs(r,'html.parser')
table = soup.find_all('table')
for n in range (0,3):
    for rows in table[n].find_all('tr'):
        row = rows.find_all('td')
        for links in row:
            link = links.find('a')
            if link:
                href_value = link.get('href')
                l = f'https://www.valueresearchstocks.com/{href_value}'
                All_Links.append(l)

for link in All_Links:
    try:
        driver.get(link)
        # Add cookies to maintain session
        for cookie in cookies:
            driver.add_cookie(cookie)
        # driver.find_element(By.XPATH,'//*[@id="premium-coverage-tab"]/div/div/div/ul/li[2]/a').click()
        driver.execute_script("window.scrollTo(0, 0);")
        time.sleep(1)
        element_text = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[2]/div/div[2]/a').click()
        time.sleep(5)
        new_window = driver.window_handles[-1]
        driver.switch_to.window(new_window)
        WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//*[@id="print-report"]'))).click()
        # driver.switch_to.active_element.send_keys("s")
        # time.sleep(5)
        # driver.switch_to.active_element.send_keys("file_name.pdf")
        # time.sleep(5)
        # driver.switch_to.active_element.send_keys("\n")
        time.sleep(10)
    except Exception as e:
        print(e)
# Out:
# Pop-up closed.

# %%
for link in All_Links[0:]:
    print(link) ashiana housing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for link in All_Links[0:]:
#       2     print(link)
#
# NameError: name 'All_Links' is not defined
