# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import gspread
import datetime

# %%
s = HTMLSession()
header = {
'scheme':'https',
'Accept':'application/json, text/plain, */*',
'Accept-Language':'en-US,en;q=0.8',
'Referer':'https://www.bseindia.com/',
'Sec-Ch-Ua':'"Not_A Brand";v="8", "Chromium";v="120", "Brave";v="120"',
'Sec-Ch-Ua-Mobile': '?0',
'Sec-Ch-Ua-Platform':'"Windows"',
'Sec-Fetch-Mode':'cors',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

# %%
start_date = datetime.date(2018, 1, 1)
end_date = datetime.date.today()

# %%
All_data = []
current_date = start_date
while current_date <= end_date:
    first_day = current_date.replace(day=1)
    last_day = (datetime.date(current_date.year, current_date.month % 12 + 1, 1) - datetime.timedelta(days=1))
    date_from = first_day.strftime('%Y%m%d')
    date_to = last_day.strftime('%Y%m%d')
    print(f"{date_from} to {date_to}")
    count = 1
    while True:
          url = f'https://api.bseindia.com/BseIndiaAPI/api/AnnSubCategoryGetData/w?pageno={count}&strCat=Company+Update&strPrevDate={date_from}&strScrip=&strSearch=P&strToDate={date_to}&strType=C&subcategory=Investor+Presentation'
          r = s.get(url,headers=header) 
          if 'Table' in  r.json() and r.json()['Table']:
               data = r.json()['Table']
               temp_df = pd.DataFrame(data)
               All_data.append(temp_df)
               print('Page.no =',count)
               count += 1  
          else:
               break
    current_date = datetime.date(current_date.year + current_date.month // 12, (current_date.month % 12) + 1, 1)
# Out:
# 20180101 to 20180131
# Page.no = 1
# Page.no = 2
# Page.no = 3
# 20180201 to 20180228
# Page.no = 1
# Page.no = 2
# Page.no = 3
# Page.no = 4
# Page.no = 5
# Page.no = 6
# 20180301 to 20180331
# Page.no = 1
# 20180401 to 20180430
# Page.no = 1
# Page.no = 2
# 20180501 to 20180531
# Page.no = 1
# Page.no = 2
# Page.no = 3
# Page.no = 4
# Page.no = 5
# Page.no = 6
# Page.no = 7
# 20180601 to 20180630
# Page.no = 1
# Page.no = 2
# 20180701 to 20180731
# Page.no = 1
# Page.no = 2
# Page.no = 3
# 20180801 to 20180831
# Page.no = 1
# Page.no = 2
# Page.no = 3
# Page.no = 4
# Page.no = 5
# Page.no = 6
# Page.no = 7
# 20180901 to 20180930
# Page.no = 1
# 20181001 to 20181031
# Page.no = 1
# Page.no = 2
# Page.no = 3
# Page.no = 4
# 20181101 to 20181130
# Page.no = 1
# Page.no = 2
# Page.no = 3
# Page.no = 4
# Page.no = 5
# Page.no = 6
# Page.no = 7
# 20181201 to 20171231
# 20190101 to 20190131
# Page.no = 1
# Page.no = 2
# Page.no = 3
# 20190201 to 20190228
# Page.no = 1
# Page.no = 2
# ...

# %%
Final_Data = pd.concat(All_data,ignore_index=True)
Final_Data.head(20)
# Out:
# C:\Users\Ashish Kumar Pal\AppData\Local\Temp\ipykernel_15436\3746031516.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   Final_Data = pd.concat(All_data,ignore_index=True)
#                                   NEWSID  SCRIP_CD  \
# 0   1caa21a7-df82-4403-a1ef-62c7767fd261    539844
# 1   179f12d2-9342-4faa-a9c0-0670208c8d24    534680
# 2   2926497b-ba6c-4121-a5d0-f2bbe928e646    511505
# 3   8639ef0b-5447-455b-ac18-ac196084aa47    540719
# 4   ee033c23-54b9-48ca-a75f-555fd45e2ca2    532313
# 5   1c6fff56-a492-4cbf-aca2-d9f13320021d    539551
# 6   57c337ee-8ae9-4abe-a195-e088b048302e    539118
# 7   dcfefadc-40c0-4287-9ea3-b09059096ffa    500295
# 8   f6c0636e-e1ff-49e5-abb7-c03abcdf305c    533088
# ...

# %%
Final_Data.to_csv(f'Invester_Presentation{datetime.datetime.now().strftime('%d-%m-%Y')}.csv')
